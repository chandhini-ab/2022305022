# %% [markdown]
# <a href="https://colab.research.google.com/github/chandhini-ab/2022305022/blob/main/text%20to%20speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install required packages
# !pip install gTTS

# Step 2: Import necessary modules
from gtts import gTTS
from IPython.display import Audio
import os

# Step 3: Take user input
text = input("Enter text you want to convert to speech: ")
language = input("Enter language code (e.g., 'en' for English, 'hi' for Hindi): ")

# Step 4: Convert text to speech
try:
    tts = gTTS(text=text, lang=language)
    tts.save("output.mp3")
    print("✅ Speech generated successfully!")

    # Step 5: Play the audio
    display(Audio("output.mp3", autoplay=True))

except Exception as e:
    print(f"❌ Error occurred: {e}")
# Out:
# ...
# Enter text you want to convert to speech: i want holidays
# Enter language code (e.g., 'en' for English, 'hi' for Hindi): en
# ✅ Speech generated successfully!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
